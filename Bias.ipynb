# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.choice(["Head","Tail"])
# Out:
# 'Tail'

# %%
throw=[]
for i in range(1000000):
    toss=np.random.choice(["Head","Tail"])
    throw.append(toss)

# %%
plt.hist(throw,bins=10)
plt.show()

# %%
one=np.random.choice(range(1,7))
two=np.random.choice(range(1,7))
total=one+two
total
# Out:
# 11

# %%
throw1=[]
for i in range(1000000):
    toss=np.random.choice(["Head","Tail"],p=[7/8,1/8])
    throw1.append(toss)

plt.hist(throw,bins=10)
plt.show()

# %%
throw2=[]
for i in range(1000000):
    one=np.random.choice([1,2,3,4,5,6],p=[7/12,1/12,1/12,1/12,1/12,1/12])
    two=np.random.choice([1,2,3,4,5,6],p=[7/12,1/12,1/12,1/12,1/12,1/12])
    total=one+two
    throw2.append(total)

plt.hist(throw2,bins=30)
plt.show()

# %%
throw3=[]
for i in range(1000000):
    one=np.random.choice(range(1,7))
    two=np.random.choice(range(1,7))
    total=one+two
    throw3.append(total)

plt.hist(throw3,bins=10)
plt.show()
