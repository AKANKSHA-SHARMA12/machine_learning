# %% [markdown]
# Visualization helps to factually answer a lot of controversial questions.

# %% [raw]
# Some controversial questions that we will uncover in this file are:
# Q1. Are males better than females at maths?
# Q2.Are females better than males at reading & writing?
# Q3.Are people from certain race/caste/religion generally better at Maths than other?
# Q4.Is parents education a factor for Kids performance in school?
# Q5.If the students are well fed with proper nutrious food,they are more likely to perform better?
# Q6.If the kids are provided with a supplementry coaching/test,they are more likely to perform better.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("student performance.csv")

# %%
dataset.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Step to rename columns
dataset.columns=["gender","race","ple","lunch","test","math","reading","writing"]

# %%
dataset.columns
# Out:
# Index(['gender', 'race', 'ple', 'lunch', 'test', 'math', 'reading', 'writing'], dtype='object')

# %%
dataset.describe()
# Out:
#              math      reading      writing
# count  1000.00000  1000.000000  1000.000000
# mean     66.08900    69.169000    68.054000
# std      15.16308    14.600192    15.195657
# min       0.00000    17.000000    10.000000
# 25%      57.00000    59.000000    57.750000
# 50%      66.00000    70.000000    69.000000
# 75%      77.00000    79.000000    79.000000
# max     100.00000   100.000000   100.000000

# %% [raw]
# From above we can conclude that minimum marks scored in maths is 0 ,reading is 17 & writing is 10.Similarly maximum marks scored is 100 in each.
# further the avg marks in maths , reading , writing are 66,69,68 respectively.Which further indicates that avg performace is poor in maths comparitively to reading and writing.

# %%
#Visualization

# %%
plt.scatter(dataset["math"],dataset["reading"])   #SCATTER PLOT
plt.show()

# %% [raw]
# pd.plotting.scatter_matrix(
#     frame,
#     alpha=0.5,
#     figsize=None,
#     ax=None,
#     grid=False,
#     diagonal='hist',
#     marker='.',
#     density_kwds=None,
#     hist_kwds=None,
#     range_padding=0.05,
#     **kwds,
# )
# Docstring:
# Draw a matrix of scatter plots.
#
# Parameters
# ----------
# frame : DataFrame
# alpha : float, optional
#     amount of transparency applied
# figsize : (float,float), optional
#     a tuple (width, height) in inches
# ax : Matplotlib axis object, optional
# grid : bool, optional
#     setting this to True will show the grid
# diagonal : {'hist', 'kde'}
#     pick between 'kde' and 'hist' for
#     either Kernel Density Estimation or Histogram
#     plot in the diagonal
# marker : str, optional
#     Matplotlib marker type, default '.'
# hist_kwds : other plotting keyword arguments
#     To be passed to hist function
# density_kwds : other plotting keyword arguments
#     To be passed to kernel density estimate plot
# range_padding : float, optional
#     relative extension of axis range in x and y
#     with respect to (x_max - x_min) or (y_max - y_min),
#     default 0.05
# kwds : other plotting keyword arguments
#     To be passed to scatter function

# %%
#PLOTING FOR ALL THE NUMERICAL VARIABLES...HERE WE HAVE 3 NUMERIC VARIABLES HENCE A MATRIX OF 3x3 WILL BE FORMED.
pd.plotting.scatter_matrix(dataset)
plt.show()

# %%
sns.pairplot(dataset)
plt.show()

# %%
dataset["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
dataset["gender"].value_counts().values
# Out:
# array([518, 482], dtype=int64)

# %%
dataset["gender"].value_counts().index
# Out:
# Index(['female', 'male'], dtype='object')

# %%
dataset["race"].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race, dtype: int64

# %%
per=dataset["ple"].value_counts()/dataset.shape[0]*100  #percentage of parents in terms of education
per
# Out:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: ple, dtype: float64

# %% [markdown]
# Q WHAT IS THE RANGE IN WHICH MOST STUDENTS LIE AS FAR AS MATHS IS CONCERNED?

# %%
plt.hist(dataset["math"],bins=100)
plt.show()  # 40 to 85

# %%
plt.hist(dataset["reading"],bins=50)
plt.show()

# %%
plt.hist(dataset["writing"],bins=50)
plt.show()

# %% [markdown]
# Q1. Are males better than females at maths?

# %%
sns.barplot(dataset["gender"],dataset["math"])
plt.show()

# %% [markdown]
# Q2.Are females better than males at reading & writing?

# %%
sns.barplot(dataset["gender"],dataset["reading"])
plt.show()

# %%
sns.barplot(dataset["gender"],dataset["writing"])
plt.show()

# %% [markdown]
# Q3.Are people from certain race/caste/religion generally better at Maths than other?

# %%
sns.barplot(dataset["race"],dataset["math"])
plt.show()

# %%
sns.barplot(dataset["race"],dataset["math"],dataset["gender"])
plt.show() #group E(high)  group A(low)

# %% [markdown]
# Q4.Is parents education a factor for Kids performance in school?

# %%
sns.barplot(dataset["ple"],dataset["math"])
plt.show() #impacts only the kids of uneducated

# %%
sns.barplot(dataset["ple"],dataset["math"],dataset["gender"])
plt.show()

# %%
sns.barplot(dataset["ple"],dataset["reading"])
plt.show()

# %%
sns.barplot(dataset["ple"],dataset["writing"])
plt.show()

# %% [markdown]
# Q5.If the students are well fed with proper nutrious food,they are more likely to perform better?

# %%
sns.barplot(dataset["lunch"],dataset["math"],dataset["gender"])
plt.show()

# %%
sns.barplot(dataset["lunch"],dataset["reading"],dataset["gender"])
plt.show()

# %%
sns.barplot(dataset["lunch"],dataset["writing"],dataset["gender"])
plt.show()

# %% [markdown]
# Q6.If the kids are provided with a supplementry coaching/test,they are more likely to perform better.

# %%
sns.barplot(dataset["test"],dataset["math"],dataset["gender"])
plt.show()

# %%
sns.barplot(dataset["test"],dataset["reading"],dataset["gender"])
plt.show()

# %%
sns.barplot(dataset["test"],dataset["writing"],dataset["gender"])
plt.show()

# %%
sns.boxplot(dataset["gender"],dataset["math"])

# %%
sns.boxplot(dataset["race"],dataset["math"])

# %%
sns.boxplot(dataset["lunch"],dataset["math"])

# %%
sns.boxplot(dataset["ple"],dataset["math"])
